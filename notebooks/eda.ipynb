# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/customer_churn_pipeline_dataset.csv")
df.head()
# Out:
#    CustomerAge  TenureMonths  MonthlySpend  NumServices    ContractType  \
# 0           57            55         47.23            1  Month-to-month
# 1           65            11        118.89            5  Month-to-month
# 2           56             2        151.08            2        One year
# 3           41            40        121.46            1        One year
# 4           67            36        159.51            4  Month-to-month
#
#       PaymentMethod InternetService TechSupport StreamingServices Churn
# 0       Credit card     Fiber optic          No               Yes   Yes
# 1  Electronic check             DSL         Yes               Yes   Yes
# 2  Electronic check             NaN          No                No    No
# 3       Credit card             DSL          No               Yes    No
# 4  Electronic check             DSL         Yes               Yes   Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerAge        2000 non-null   int64
#  1   TenureMonths       2000 non-null   int64
#  2   MonthlySpend       2000 non-null   float64
#  3   NumServices        2000 non-null   int64
#  4   ContractType       2000 non-null   object
#  5   PaymentMethod      2000 non-null   object
#  6   InternetService    1696 non-null   object
#  7   TechSupport        2000 non-null   object
#  8   StreamingServices  2000 non-null   object
#  9   Churn              2000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 156.4+ KB

# %%
df.isnull().sum()
# Out:
# CustomerAge            0
# TenureMonths           0
# MonthlySpend           0
# NumServices            0
# ContractType           0
# PaymentMethod          0
# InternetService      304
# TechSupport            0
# StreamingServices      0
# Churn                  0
# dtype: int64

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     1161
# Yes     839
# Name: count, dtype: int64

# %%
sns.boxplot(x="Churn", y="MonthlySpend", data=df )
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlySpend'>

# %%
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    plt.figure(figsize=(10,6))
    sns.histplot(x=df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
sns.pairplot(df, hue="Churn")

# %%
df.dropna(inplace=True)
